# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os

# %% [markdown]
# # Customer Lead Generator Dataset

# %%
data_folder = 'data'
filename = 'CustomerData_LeadGenerator.csv'

# %%
customer_data_path = os.path.join(data_folder, filename)
customer_data = pd.read_csv(customer_data_path)

customer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3773 entries, 0 to 3772
# Data columns (total 26 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   fakeID                                          3773 non-null   object
#  1   b_specialisation_i                              3773 non-null   int64
#  2   b_specialisation_h                              3773 non-null   int64
#  3   b_specialisation_g                              3773 non-null   int64
#  4   b_specialisation_f                              3773 non-null   int64
#  5   b_specialisation_e                              3773 non-null   int64
#  6   b_specialisation_d                              3773 non-null   int64
#  7   b_specialisation_c                              3773 non-null   int64
#  8   b_specialisation_b                              3773 non-null   int64
#  9   b_specialisation_a                              3773 non-null   int64
#  10  b_specialisation_j                              3773 non-null   int64
#  11  q_OpeningDays                                   3773 non-null   int64
#  12  q_OpeningHours                                  3773 non-null   object
#  13  q_2017 Average Household Size                   3773 non-null   float64
#  14  q_2017 Total Households                         3773 non-null   int64
#  15  q_2017 HHs: 5th Quintile (68.759 and above)     3773 non-null   int64
#  16  q_5th Quint by Total HH                         3773 non-null   float64
#  17  q_2017 Purchasing Power: Per Capita             3773 non-null   float64
#  18  q_2017 Total Population                         3773 non-null   int64
#  19  q_2017 Pop 15+/Edu: University, Fachhochschule  3773 non-null   int64
#  20  q_Uni by Total Pop                              3773 non-null   float64
#  21  q_2017 Personal Care: Per Capita                3773 non-null   float64
#  22  q_2017 Medical Products: Per Capita             3773 non-null   float64
#  23  q_2017 Personal Effects: Per Capita             3773 non-null   float64
#  24  b_in_kontakt_gewesen                            3773 non-null   int64
#  25  b_gekauft_gesamt                                3773 non-null   int64
# dtypes: float64(7), int64(17), object(2)
# memory usage: 766.5+ KB

# %%
customer_data.head()
# Out:
#       fakeID  b_specialisation_i  b_specialisation_h  b_specialisation_g  \
# 0  1069_7334                   0                   0                   0
# 1   328_2350                   0                   0                   0
# 2   865_6285                   0                   0                   0
# 3     47_307                   0                   1                   1
# 4   342_2513                   0                   0                   0
#
#    b_specialisation_f  b_specialisation_e  b_specialisation_d  \
# 0                   0                   0                   0
# 1                   1                   1                   1
# 2                   1                   0                   1
# 3                   0                   0                   0
# 4                   0                   0                   1
#
#    b_specialisation_c  b_specialisation_b  b_specialisation_a  ...  \
# 0                   0                   0                   0  ...
# 1                   0                   0                   0  ...
# 2                   0                   0                   0  ...
# 3                   0                   0                   0  ...
# 4                   0                   0                   0  ...
#
#    q_5th Quint by Total HH  q_2017 Purchasing Power: Per Capita  \
# 0                 0.186735                             23730.35
# 1                 0.179848                             23343.26
# 2                 0.184935                             23674.18
# 3                 0.184523                             23572.26
# 4                 0.189871                             23821.63
#
#   q_2017 Total Population  q_2017 Pop 15+/Edu: University, Fachhochschule  \
# 0                 2194057                                          324656
# 1                 1966798                                          281130
# 2                 2149624                                          320326
# 3                 2161445                                          310981
# 4                 2302959                                          334940
#
#    q_Uni by Total Pop  q_2017 Personal Care: Per Capita  \
# 0            0.147971                            593.19
# 1            0.142938                            588.54
# 2            0.149015                            592.88
# 3            0.143876                            590.84
# 4            0.145439                            593.56
#
#    q_2017 Medical Products: Per Capita  q_2017 Personal Effects: Per Capita  \
# 0                               326.28                               235.75
# 1                               320.36                               230.66
# 2                               325.57                               234.82
# 3                               324.06                               233.81
# 4                               327.75                               237.41
#
#    b_in_kontakt_gewesen  b_gekauft_gesamt
# 0                     1                 1
# 1                     1                 1
# 2                     1                 1
# 3                     1                 0
# 4                     1                 1
#
# [5 rows x 26 columns]

# %%
customer_data.iloc[:4, 10:]
# Out:
#    b_specialisation_j  q_OpeningDays q_OpeningHours  \
# 0                   1              4             36
# 1                   0              4             20
# 2                   1              0              0
# 3                   0              4             20
#
#    q_2017 Average Household Size  q_2017 Total Households  \
# 0                            2.1                  1045481
# 1                            2.1                   935739
# 2                            2.1                  1026235
# 3                            2.1                  1027701
#
#    q_2017 HHs: 5th Quintile (68.759 and above)  q_5th Quint by Total HH  \
# 0                                       195228                 0.186735
# 1                                       168291                 0.179848
# 2                                       189787                 0.184935
# 3                                       189634                 0.184523
#
#    q_2017 Purchasing Power: Per Capita  q_2017 Total Population  \
# 0                             23730.35                  2194057
# 1                             23343.26                  1966798
# 2                             23674.18                  2149624
# 3                             23572.26                  2161445
#
#    q_2017 Pop 15+/Edu: University, Fachhochschule  q_Uni by Total Pop  \
# 0                                          324656            0.147971
# 1                                          281130            0.142938
# 2                                          320326            0.149015
# 3                                          310981            0.143876
#
#    q_2017 Personal Care: Per Capita  q_2017 Medical Products: Per Capita  \
# 0                            593.19                               326.28
# 1                            588.54                               320.36
# 2                            592.88                               325.57
# 3                            590.84                               324.06
#
#    q_2017 Personal Effects: Per Capita  b_in_kontakt_gewesen  b_gekauft_gesamt
# 0                               235.75                     1                 1
# 1                               230.66                     1                 1
# 2                               234.82                     1                 1
# 3                               233.81                     1                 0

# %%
customer_data.isnull().sum()
# Out:
# fakeID                                            0
# b_specialisation_i                                0
# b_specialisation_h                                0
# b_specialisation_g                                0
# b_specialisation_f                                0
# b_specialisation_e                                0
# b_specialisation_d                                0
# b_specialisation_c                                0
# b_specialisation_b                                0
# b_specialisation_a                                0
# b_specialisation_j                                0
# q_OpeningDays                                     0
# q_OpeningHours                                    0
# q_2017 Average Household Size                     0
# q_2017 Total Households                           0
# q_2017 HHs: 5th Quintile (68.759 and above)       0
# q_5th Quint by Total HH                           0
# q_2017 Purchasing Power: Per Capita               0
# q_2017 Total Population                           0
# q_2017 Pop 15+/Edu: University, Fachhochschule    0
# q_Uni by Total Pop                                0
# q_2017 Personal Care: Per Capita                  0
# q_2017 Medical Products: Per Capita               0
# q_2017 Personal Effects: Per Capita               0
# b_in_kontakt_gewesen                              0
# b_gekauft_gesamt                                  0
# dtype: int64

# %%
customer_data.describe()
# Out:
#        b_specialisation_i  b_specialisation_h  b_specialisation_g  \
# count         3773.000000         3773.000000         3773.000000
# mean             0.218129            0.224225            0.254704
# std              0.413030            0.417126            0.435753
# min              0.000000            0.000000            0.000000
# 25%              0.000000            0.000000            0.000000
# 50%              0.000000            0.000000            0.000000
# 75%              0.000000            0.000000            1.000000
# max              1.000000            1.000000            1.000000
#
#        b_specialisation_f  b_specialisation_e  b_specialisation_d  \
# count         3773.000000         3773.000000         3773.000000
# mean             0.111582            0.285449            0.005566
# std              0.314894            0.451688            0.074407
# min              0.000000            0.000000            0.000000
# 25%              0.000000            0.000000            0.000000
# 50%              0.000000            0.000000            0.000000
# 75%              0.000000            1.000000            0.000000
# max              1.000000            1.000000            1.000000
#
#        b_specialisation_c  b_specialisation_b  b_specialisation_a  \
# count         3773.000000         3773.000000         3773.000000
# mean             0.002650            0.020408            0.138616
# std              0.051421            0.141411            0.345592
# min              0.000000            0.000000            0.000000
# 25%              0.000000            0.000000            0.000000
# 50%              0.000000            0.000000            0.000000
# 75%              0.000000            0.000000            0.000000
# max              1.000000            1.000000            1.000000
#
#        b_specialisation_j  ...  q_5th Quint by Total HH  \
# count         3773.000000  ...              3773.000000
# mean             0.254174  ...                 0.197419
# std              0.435454  ...                 0.024973
# min              0.000000  ...                 0.100814
# 25%              0.000000  ...                 0.184566
# 50%              0.000000  ...                 0.195882
# 75%              1.000000  ...                 0.213667
# max              1.000000  ...                 0.269397
#
#        q_2017 Purchasing Power: Per Capita  q_2017 Total Population  \
# count                          3773.000000             3.773000e+03
# mean                          23170.651983             8.257315e+05
# std                            1147.978703             8.565966e+05
# min                           19171.140000             3.807000e+03
# 25%                           22662.050000             1.780610e+05
# 50%                           23627.240000             3.417850e+05
# 75%                           23839.540000             2.023342e+06
# max                           26008.530000             2.350279e+06
#
#        q_2017 Pop 15+/Edu: University, Fachhochschule  q_Uni by Total Pop  \
# count                                     3773.000000         3773.000000
# mean                                    111252.936920            0.101737
# std                                     131837.721022            0.039749
# min                                        172.000000            0.027974
# 25%                                      11431.000000            0.063095
# 50%                                      39282.000000            0.101592
# 75%                                     298968.000000            0.145630
# max                                     337338.000000            0.170786
#
#        q_2017 Personal Care: Per Capita  q_2017 Medical Products: Per Capita  \
# count                       3773.000000                          3773.000000
# mean                         574.247339                           326.438110
# std                           22.966321                            11.135183
# min                          490.390000                           270.110000
# 25%                          560.130000                           322.380000
# 50%                          584.000000                           325.860000
# 75%                          592.520000                           331.930000
# max                          610.140000                           363.230000
#
#        q_2017 Personal Effects: Per Capita  b_in_kontakt_gewesen  \
# count                          3773.000000           3773.000000
# mean                            234.848630              0.025179
# std                              11.018168              0.156689
# min                             196.450000              0.000000
# 25%                             231.310000              0.000000
# 50%                             235.290000              0.000000
# 75%                             238.000000              0.000000
# max                             274.140000              1.000000
#
#        b_gekauft_gesamt
# count       3773.000000
# mean           0.015107
# std            0.121996
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.000000
# max            1.000000
#
# [8 rows x 24 columns]

# %%
customer_data.iloc[:, 10:].describe()
# Out:
#        b_specialisation_j  q_OpeningDays  q_2017 Average Household Size  \
# count         3773.000000    3773.000000                    3773.000000
# mean             0.254174       3.230586                       2.242221
# std              0.435454       2.070304                       0.153143
# min              0.000000       0.000000                       2.000000
# 25%              0.000000       0.000000                       2.100000
# 50%              0.000000       4.000000                       2.200000
# 75%              1.000000       5.000000                       2.400000
# max              1.000000       7.000000                       2.900000
#
#        q_2017 Total Households  q_2017 HHs: 5th Quintile (68.759 and above)  \
# count             3.773000e+03                                  3773.000000
# mean              3.873879e+05                                 73575.237477
# std               4.116316e+05                                 75533.849191
# min               1.718000e+03                                   316.000000
# 25%               7.571800e+04                                 15441.000000
# 50%               1.537120e+05                                 34165.000000
# 75%               9.651600e+05                                174038.000000
# max               1.113261e+06                                212126.000000
#
#        q_5th Quint by Total HH  q_2017 Purchasing Power: Per Capita  \
# count              3773.000000                          3773.000000
# mean                  0.197419                         23170.651983
# std                   0.024973                          1147.978703
# min                   0.100814                         19171.140000
# 25%                   0.184566                         22662.050000
# 50%                   0.195882                         23627.240000
# 75%                   0.213667                         23839.540000
# max                   0.269397                         26008.530000
#
#        q_2017 Total Population  \
# count             3.773000e+03
# mean              8.257315e+05
# std               8.565966e+05
# min               3.807000e+03
# 25%               1.780610e+05
# 50%               3.417850e+05
# 75%               2.023342e+06
# max               2.350279e+06
#
#        q_2017 Pop 15+/Edu: University, Fachhochschule  q_Uni by Total Pop  \
# count                                     3773.000000         3773.000000
# mean                                    111252.936920            0.101737
# std                                     131837.721022            0.039749
# min                                        172.000000            0.027974
# 25%                                      11431.000000            0.063095
# 50%                                      39282.000000            0.101592
# 75%                                     298968.000000            0.145630
# max                                     337338.000000            0.170786
#
#        q_2017 Personal Care: Per Capita  q_2017 Medical Products: Per Capita  \
# count                       3773.000000                          3773.000000
# mean                         574.247339                           326.438110
# std                           22.966321                            11.135183
# min                          490.390000                           270.110000
# 25%                          560.130000                           322.380000
# 50%                          584.000000                           325.860000
# 75%                          592.520000                           331.930000
# max                          610.140000                           363.230000
#
#        q_2017 Personal Effects: Per Capita  b_in_kontakt_gewesen  \
# count                          3773.000000           3773.000000
# mean                            234.848630              0.025179
# std                              11.018168              0.156689
# min                             196.450000              0.000000
# 25%                             231.310000              0.000000
# 50%                             235.290000              0.000000
# 75%                             238.000000              0.000000
# max                             274.140000              1.000000
#
#        b_gekauft_gesamt
# count       3773.000000
# mean           0.015107
# std            0.121996
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.000000
# max            1.000000

# %%
# Assessing the class distribution for 'b_in_kontakt_gewesen' and 'b_gekauft_gesamt'
class_distribution = {
    "b_in_kontakt_gewesen": customer_data['b_in_kontakt_gewesen'].value_counts(normalize=True),
    "b_gekauft_gesamt": customer_data['b_gekauft_gesamt'].value_counts(normalize=True)
}

class_distribution
# Out:
# {'b_in_kontakt_gewesen': b_in_kontakt_gewesen
#  0    0.974821
#  1    0.025179
#  Name: proportion, dtype: float64,
#  'b_gekauft_gesamt': b_gekauft_gesamt
#  0    0.984893
#  1    0.015107
#  Name: proportion, dtype: float64}

# %% [markdown]
# ### Class Distribution Analysis
#
# The class distribution for the two key variables is as follows:
#
# *   **`b_in_kontakt_gewesen`** (whether there has been contact):
#     *   No Contact (0): 97.48%
#     *   Contact (1): 2.52%
# *   **`b_gekauft_gesamt`** (whether a purchase was made):
#     *   No Purchase (0): 98.49%
#     *   Purchase (1): 1.51%
#
# This confirms the presence of imbalanced classes, especially for `b_gekauft_gesamt`, where the proportion of positive cases (purchases made) is very low. Handling imbalanced datasets is crucial for predictive modeling since it can significantly bias the model towards the majority class, resulting in poor predictive performance on the minority class, which is often the class of interest.
#
# ### Addressing Imbalanced Classes
#
# Several strategies can be employed to address imbalanced classes:
#
# 1.  **Resampling Techniques**:
#
#     *   **Oversampling** the minority class or **undersampling** the majority class can help balance the classes. Techniques like SMOTE (Synthetic Minority Over-sampling Technique) can be used to synthetically generate new examples.
# 2.  **Altered Class Weights**:
#
#     *   Some algorithms allow for weighting the classes differently to penalize misclassifications of the minority class more than those of the majority class.
# 3.  **Evaluation Metrics**:
#
#     *   Using evaluation metrics that provide more insight into the performance on the minority class, such as precision, recall, F1-score (harmonic mean of precision and recall), and ROC-AUC, instead of relying solely on accuracy.
#
# ### Project Formulation
#
# Given the insights from the dataset, a potential project could involve developing a predictive model to **forecast whether a customer will make a purchase**, using `b_gekauft_gesamt` as the label. This model could leverage features like customer specialisation, demographic data, and economic indicators, while applying techniques to handle the imbalanced dataset.
#
# **Steps for the Project**:
#
# 1.  **Data Preprocessing**: Clean and prepare the data, possibly including encoding categorical variables (if any beyond `fakeID` and `q_OpeningHours`), normalizing numerical variables, and handling the `q_OpeningHours` object data.
#
# 2.  **Feature Engineering and Selection**: Identify the most relevant features for the predictive model. This might involve analyzing correlations or using machine learning models to assess feature importance.
#
# 3.  **Model Development**: Train machine learning models suited for binary classification problems. Given the imbalanced nature of the dataset, models that offer flexibility in handling class imbalance, such as Random Forests or Gradient Boosting Machines, could be appropriate. Experiment with different resampling techniques or class weights as part of the modeling process.
#
# 4.  **Evaluation and Optimization**: Use appropriate metrics to evaluate model performance, focusing on the minority class's predictive accuracy. This could involve cross-validation techniques to ensure the model's generalizability.
#
#
# This project aims to enhance customer targeting by predicting purchase likelihood, potentially leading to more efficient use of marketing resources and improved customer engagement strategies. ​

# %% [markdown]
# ## 1. Data Preprocessing
# ### Handling the `q_OpeningHours` object column

# %%
customer_data['q_OpeningHours'].unique()
# Out:
# array(['36', '20', '0', '33', '17', '23', '21', '30.5', '12', '29', '53',
#        '32', '27', '39', '24', '20.5', '35', '30', '45', '34', '9', '10',
#        '16', '22', '25', '15', '36.5', '68', '23.5', '5', '42', '21.5',
#        '19', '28', '25.5', '7', '37', '4', '18', '31.5', '26.5', '31',
#        '28.5', '8', '40', '37.5', '17.5', '19.5', '14', '29.5', '26',
#        '16.5', '11', '27.5', '47', '6', '20.25', '13', '15.5', '18.25',
#        '22.5', '41', '38', '33.5', '24.5', '18.5', '30.25', '28.16666667',
#        '28.75', '38.5', '12.5', '4.5', '32.5', '2.75', '50', '35.5', '3',
#        '25.25', '19.71666667', '39.5', '11.5', '13.5', '47.5', '43',
#        '34.5', '41.5', '46.5', '57.5', '42.5', '42.25', '54', '49.5',
#        '55', '60', '37.25', '44', '10.5', '38.25', 'ject', '32.75', '3.5',
#        '24.45', '36.16666667', '46.25', '48', '57', '7.5', '33.25',
#        '40.5', '22.25', '46', '27.75', '26.75', '26.25', '25.75', '6.5',
#        '2'], dtype=object)

# %%
customer_data[customer_data['q_OpeningHours'] == 'ject']
# Out:
#         fakeID  b_specialisation_i  b_specialisation_h  b_specialisation_g  \
# 2099  363_2645                   0                   1                   0
#
#       b_specialisation_f  b_specialisation_e  b_specialisation_d  \
# 2099                   0                   1                   0
#
#       b_specialisation_c  b_specialisation_b  b_specialisation_a  ...  \
# 2099                   0                   0                   0  ...
#
#       q_5th Quint by Total HH  q_2017 Purchasing Power: Per Capita  \
# 2099                  0.18607                             23718.72
#
#      q_2017 Total Population  q_2017 Pop 15+/Edu: University, Fachhochschule  \
# 2099                 2155666                                          322671
#
#       q_Uni by Total Pop  q_2017 Personal Care: Per Capita  \
# 2099            0.149685                            593.28
#
#       q_2017 Medical Products: Per Capita  \
# 2099                               326.52
#
#       q_2017 Personal Effects: Per Capita  b_in_kontakt_gewesen  \
# 2099                               235.49                     0
#
#       b_gekauft_gesamt
# 2099                 0
#
# [1 rows x 26 columns]

# %%
customer_data[customer_data['q_OpeningHours'] == 'ject'].iloc[:4, 10:]
# Out:
#       b_specialisation_j  q_OpeningDays q_OpeningHours  \
# 2099                   0              4           ject
#
#       q_2017 Average Household Size  q_2017 Total Households  \
# 2099                            2.1                  1029051
#
#       q_2017 HHs: 5th Quintile (68.759 and above)  q_5th Quint by Total HH  \
# 2099                                       191476                  0.18607
#
#       q_2017 Purchasing Power: Per Capita  q_2017 Total Population  \
# 2099                             23718.72                  2155666
#
#       q_2017 Pop 15+/Edu: University, Fachhochschule  q_Uni by Total Pop  \
# 2099                                          322671            0.149685
#
#       q_2017 Personal Care: Per Capita  q_2017 Medical Products: Per Capita  \
# 2099                            593.28                               326.52
#
#       q_2017 Personal Effects: Per Capita  b_in_kontakt_gewesen  \
# 2099                               235.49                     0
#
#       b_gekauft_gesamt
# 2099                 0

# %% [markdown]
# There is only one row where `q_OpeningHours` column value is "ject", which is likely a typo or an error in the data.
# First step is to replace this value with NaN and cast the column to float.
# Then I would plot the distribution of the column and decide whether to impute the missing value with e.g. mean or remove this row completely.

# %%
# Convert the column to numeric, replacing "ject" with NaN
customer_data['q_OpeningHours'] = pd.to_numeric(customer_data['q_OpeningHours'], errors='coerce')

# %%
customer_data.iloc[:, 11:].describe()
# Out:
#        q_OpeningDays  q_OpeningHours  q_2017 Average Household Size  \
# count    3773.000000     3772.000000                    3773.000000
# mean        3.230586       18.618704                       2.242221
# std         2.070304       13.041684                       0.153143
# min         0.000000        0.000000                       2.000000
# 25%         0.000000        0.000000                       2.100000
# 50%         4.000000       21.000000                       2.200000
# 75%         5.000000       28.000000                       2.400000
# max         7.000000       68.000000                       2.900000
#
#        q_2017 Total Households  q_2017 HHs: 5th Quintile (68.759 and above)  \
# count             3.773000e+03                                  3773.000000
# mean              3.873879e+05                                 73575.237477
# std               4.116316e+05                                 75533.849191
# min               1.718000e+03                                   316.000000
# 25%               7.571800e+04                                 15441.000000
# 50%               1.537120e+05                                 34165.000000
# 75%               9.651600e+05                                174038.000000
# max               1.113261e+06                                212126.000000
#
#        q_5th Quint by Total HH  q_2017 Purchasing Power: Per Capita  \
# count              3773.000000                          3773.000000
# mean                  0.197419                         23170.651983
# std                   0.024973                          1147.978703
# min                   0.100814                         19171.140000
# 25%                   0.184566                         22662.050000
# 50%                   0.195882                         23627.240000
# 75%                   0.213667                         23839.540000
# max                   0.269397                         26008.530000
#
#        q_2017 Total Population  \
# count             3.773000e+03
# mean              8.257315e+05
# std               8.565966e+05
# min               3.807000e+03
# 25%               1.780610e+05
# 50%               3.417850e+05
# 75%               2.023342e+06
# max               2.350279e+06
#
#        q_2017 Pop 15+/Edu: University, Fachhochschule  q_Uni by Total Pop  \
# count                                     3773.000000         3773.000000
# mean                                    111252.936920            0.101737
# std                                     131837.721022            0.039749
# min                                        172.000000            0.027974
# 25%                                      11431.000000            0.063095
# 50%                                      39282.000000            0.101592
# 75%                                     298968.000000            0.145630
# max                                     337338.000000            0.170786
#
#        q_2017 Personal Care: Per Capita  q_2017 Medical Products: Per Capita  \
# count                       3773.000000                          3773.000000
# mean                         574.247339                           326.438110
# std                           22.966321                            11.135183
# min                          490.390000                           270.110000
# 25%                          560.130000                           322.380000
# 50%                          584.000000                           325.860000
# 75%                          592.520000                           331.930000
# max                          610.140000                           363.230000
#
#        q_2017 Personal Effects: Per Capita  b_in_kontakt_gewesen  \
# count                          3773.000000           3773.000000
# mean                            234.848630              0.025179
# std                              11.018168              0.156689
# min                             196.450000              0.000000
# 25%                             231.310000              0.000000
# 50%                             235.290000              0.000000
# 75%                             238.000000              0.000000
# max                             274.140000              1.000000
#
#        b_gekauft_gesamt
# count       3773.000000
# mean           0.015107
# std            0.121996
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.000000
# max            1.000000

# %% [markdown]
# ### Dropping `fakeID` object column

# %%
print(len(customer_data))
customer_data['fakeID'].nunique()
# Out:
# 3773
# 3773

# %% [markdown]
# 'fakeID' values are all unique and provide no useful information, so one can drop this column.
# `df` is the final DataFrame that will be used for modelling.

# %%
df = customer_data.drop('fakeID', axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3773 entries, 0 to 3772
# Data columns (total 25 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   b_specialisation_i                              3773 non-null   int64
#  1   b_specialisation_h                              3773 non-null   int64
#  2   b_specialisation_g                              3773 non-null   int64
#  3   b_specialisation_f                              3773 non-null   int64
#  4   b_specialisation_e                              3773 non-null   int64
#  5   b_specialisation_d                              3773 non-null   int64
#  6   b_specialisation_c                              3773 non-null   int64
#  7   b_specialisation_b                              3773 non-null   int64
#  8   b_specialisation_a                              3773 non-null   int64
#  9   b_specialisation_j                              3773 non-null   int64
#  10  q_OpeningDays                                   3773 non-null   int64
#  11  q_OpeningHours                                  3772 non-null   float64
#  12  q_2017 Average Household Size                   3773 non-null   float64
#  13  q_2017 Total Households                         3773 non-null   int64
#  14  q_2017 HHs: 5th Quintile (68.759 and above)     3773 non-null   int64
#  15  q_5th Quint by Total HH                         3773 non-null   float64
#  16  q_2017 Purchasing Power: Per Capita             3773 non-null   float64
#  17  q_2017 Total Population                         3773 non-null   int64
#  18  q_2017 Pop 15+/Edu: University, Fachhochschule  3773 non-null   int64
#  19  q_Uni by Total Pop                              3773 non-null   float64
#  20  q_2017 Personal Care: Per Capita                3773 non-null   float64
#  21  q_2017 Medical Products: Per Capita             3773 non-null   float64
#  22  q_2017 Personal Effects: Per Capita             3773 non-null   float64
#  23  b_in_kontakt_gewesen                            3773 non-null   int64
#  24  b_gekauft_gesamt                                3773 non-null   int64
# dtypes: float64(8), int64(17)
# memory usage: 737.0 KB

# %% [markdown]
# ### Data Visualisation

# %%
# Plot histograms for all numerical features
df.hist(figsize=(20, 15));

# %% [markdown]
# * There are 10 binary variables and 2 binary target variables, which are prabaly correlated.
# * The remaining 23 numerical variables have diffenrent ranges, some look normally distributed, some are skewed, some are bi-modal.
# * Some classification algorithms like logistic regression work better with numerical variables with similar ranges. I will normalize them using standard scaling (making mean = 0 and standard deviation = 1) before the modelling using a Pipeline.

# %% [markdown]
# ## 2. Feature Engineering and Selection
#
# Multicollinearity occurs when two or more independent variables are highly correlated with one another in a regression model (which is the basis for some classification models like logistic regression).
#
# Multicollinearity can be a problem in a regression model because we would not be able to distinguish between the individual effects of the independent variables on the dependent variable.
#
# It may not affect the accuracy of the model as much, but we might lose reliability in determining the effects of individual features in our model which can be a problem in interpretability.
#
# ### Visualizing correlations between the numerical features

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(df.corr(), annot=False, cmap='coolwarm'); #TODO plotly

# %% [markdown]
# ### Visualizing strong feature correlations > 0.9

# %%
r = df.corr()
r[abs(r) <= 0.9] = 0
plt.figure(figsize=(12, 6))
sns.heatmap(r, annot=False, vmin=-1, vmax=1, cmap='coolwarm');

# %% [markdown]
# ### Deciding which feature to drop based on lower variance

# %%
# Remove the upper half of the correlation matrix (excluding the diagonal)
r = r.where(np.triu(np.ones(r.shape), k=1).astype(bool))
# The NumPy triu function creates an upper triangular matrix of ones with the same shape as the correlation matrix.
# The k=1 parameter ensures that the diagonal and elements below it are excluded.
# The where method is then used to replace the values in the correlation matrix with NaN where the corresponding element in the upper triangular matrix is zero (False)

# Unstack the correlation matrix and sort the values to get the top correlations
top_correlations = r.unstack().sort_values(ascending=False)

# Get the top correlated pairs
highly_correlated_pairs = top_correlations[top_correlations > 0]
print(highly_correlated_pairs, '\n')

# Decide which feature to drop based on lower variance
features_to_drop = set()
for pair in highly_correlated_pairs.index:
    feature1, feature2 = pair
    variance1 = df[feature1].var()
    variance2 = df[feature2].var()
    
    # Choose the feature with lower variance to drop, because they have less information 
    if variance1 < variance2:
        feature_to_exclude = feature1
    else:
        feature_to_exclude = feature2
    
    features_to_drop.add(feature_to_exclude)
    print(f"Exclude {feature_to_exclude} from the pair {pair}")
# Out:
# q_2017 Total Population                         q_2017 Total Households                        0.999918
#                                                 q_2017 HHs: 5th Quintile (68.759 and above)    0.999324
# q_2017 HHs: 5th Quintile (68.759 and above)     q_2017 Total Households                        0.999019
# q_2017 Pop 15+/Edu: University, Fachhochschule  q_2017 Total Households                        0.997509
#                                                 q_2017 Total Population                        0.996797
#                                                 q_2017 HHs: 5th Quintile (68.759 and above)    0.995486
# q_2017 Personal Effects: Per Capita             q_2017 Purchasing Power: Per Capita            0.921639
# q_2017 Personal Care: Per Capita                q_2017 Purchasing Power: Per Capita            0.910653
# dtype: float64
#
# Exclude q_2017 Total Households from the pair ('q_2017 Total Population', 'q_2017 Total Households')
# Exclude q_2017 HHs: 5th Quintile (68.759 and above) from the pair ('q_2017 Total Population', 'q_2017 HHs: 5th Quintile (68.759 and above)')
# Exclude q_2017 HHs: 5th Quintile (68.759 and above) from the pair ('q_2017 HHs: 5th Quintile (68.759 and above)', 'q_2017 Total Households')
# Exclude q_2017 Pop 15+/Edu: University, Fachhochschule from the pair ('q_2017 Pop 15+/Edu: University, Fachhochschule', 'q_2017 Total Households')
# Exclude q_2017 Pop 15+/Edu: University, Fachhochschule from the pair ('q_2017 Pop 15+/Edu: University, Fachhochschule', 'q_2017 Total Population')
# Exclude q_2017 HHs: 5th Quintile (68.759 and above) from the pair ('q_2017 Pop 15+/Edu: University, Fachhochschule', 'q_2017 HHs: 5th Quintile (68.759 and above)')
# Exclude q_2017 Personal Effects: Per Capita from the pair ('q_2017 Personal Effects: Per Capita', 'q_2017 Purchasing Power: Per Capita')
# Exclude q_2017 Personal Care: Per Capita from the pair ('q_2017 Personal Care: Per Capita', 'q_2017 Purchasing Power: Per Capita')

# %%
features_to_drop
# Out:
# {'q_2017 HHs: 5th Quintile (68.759 and above)',
#  'q_2017 Personal Care: Per Capita',
#  'q_2017 Personal Effects: Per Capita',
#  'q_2017 Pop 15+/Edu: University, Fachhochschule',
#  'q_2017 Total Households'}

# %%
df_reduced = df.drop(columns=features_to_drop)
df_reduced.head()
# Out:
#    b_specialisation_i  b_specialisation_h  b_specialisation_g  \
# 0                   0                   0                   0
# 1                   0                   0                   0
# 2                   0                   0                   0
# 3                   0                   1                   1
# 4                   0                   0                   0
#
#    b_specialisation_f  b_specialisation_e  b_specialisation_d  \
# 0                   0                   0                   0
# 1                   1                   1                   1
# 2                   1                   0                   1
# 3                   0                   0                   0
# 4                   0                   0                   1
#
#    b_specialisation_c  b_specialisation_b  b_specialisation_a  \
# 0                   0                   0                   0
# 1                   0                   0                   0
# 2                   0                   0                   0
# 3                   0                   0                   0
# 4                   0                   0                   0
#
#    b_specialisation_j  q_OpeningDays  q_OpeningHours  \
# 0                   1              4            36.0
# 1                   0              4            20.0
# 2                   1              0             0.0
# 3                   0              4            20.0
# 4                   1              5            33.0
#
#    q_2017 Average Household Size  q_5th Quint by Total HH  \
# 0                            2.1                 0.186735
# 1                            2.1                 0.179848
# 2                            2.1                 0.184935
# 3                            2.1                 0.184523
# 4                            2.1                 0.189871
#
#    q_2017 Purchasing Power: Per Capita  q_2017 Total Population  \
# 0                             23730.35                  2194057
# 1                             23343.26                  1966798
# 2                             23674.18                  2149624
# 3                             23572.26                  2161445
# 4                             23821.63                  2302959
#
#    q_Uni by Total Pop  q_2017 Medical Products: Per Capita  \
# 0            0.147971                               326.28
# 1            0.142938                               320.36
# 2            0.149015                               325.57
# 3            0.143876                               324.06
# 4            0.145439                               327.75
#
#    b_in_kontakt_gewesen  b_gekauft_gesamt
# 0                     1                 1
# 1                     1                 1
# 2                     1                 1
# 3                     1                 0
# 4                     1                 1

# %%
sns.heatmap(df_reduced.corr(), annot=False, vmin=-1, vmax=1, cmap='coolwarm');

# %%
df_reduced.hist(figsize=(20, 15));

# %% [markdown]
# ### Check data leakage
# Last but not least, check relation between `b_in_kontakt_gewesen` and `b_gekauft_gesamt`, which are also highly correlated.

# %%
pd.crosstab(df.b_in_kontakt_gewesen, df.b_gekauft_gesamt)
# Out:
# b_gekauft_gesamt         0   1
# b_in_kontakt_gewesen
# 0                     3678   0
# 1                       38  57

# %% [markdown]
# Exclude `b_in_kontakt_gewesen` if it's leaking data: if `b_in_kontakt_gewesen == 0` then `b_gekauft_gesamt == 0`. That is, all customers who where not in contact did not make a purchase.

# %%
df.drop(columns=['b_in_kontakt_gewesen'], inplace=True)
df_reduced.drop(columns=['b_in_kontakt_gewesen'], inplace=True)

# %% [markdown]
# ### Saving preprocessed data for modelling
# As feature reduction based on correlation values might lead to important information loss, I would try modelling using both datasets:
# * __reduced__ for a baseline model using logistic regression.
# * __unreduced__ with modelling algorithms that can assess feature importance, e.g. Random Forests and XGBoost. Then it is possible to do further feature reduction.
#
# It is also possible to apply L1 (Lasso) regularization technique in logistic regression to automatically eliminate less important features, resulting in a more interpretable and potentially more efficient model.

# %%
clean_filename = filename.replace('.csv', '_clean.csv')
customer_data_path_clean = os.path.join(data_folder, clean_filename)
df.to_csv(customer_data_path_clean)

# %%
clean_reduced_filename = filename.replace('.csv', '_clean_reduced.csv')
customer_data_path_clean_reduced = os.path.join(data_folder, clean_reduced_filename)
df_reduced.to_csv(customer_data_path_clean_reduced)
